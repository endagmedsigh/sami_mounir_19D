# %%
#Uppgift a
import matplotlib.pyplot as plt
import math

x = [0,0.5]
y = [0,0.5]

plt.plot(x,y, 'o-')
plt.show()

x = 0.5
y = 0.5

c = y**2 + x**2
print(math.sqrt(c))
# Out:
# 0.7071067811865476

# %%
#Uppgift b
import matplotlib.pyplot as plt
import math

x = [0,1]
y = [0,1]

plt.plot(x,y, 'o-')
plt.show()

x = 1
y = 1

c = y**2 + x**2
print(math.sqrt(c))
# Out:
# 1.4142135623730951

# %%
#Uppgift c
import matplotlib.pyplot as plt
import math

x = [0,0.5]
y = [-0.5,0]


plt.plot(x,y, 'o-')
plt.show()

x = 0.5
y = -0.5

c = y**2 + x**2
print(math.sqrt(c))
# Out:
# 0.7071067811865476

# %%
#Uppgift d
import matplotlib.pyplot as plt
import random

for g in range(10):  #Här skapar vi våran loop
    x = random.uniform(-1,1)  # X, detta är våran första randomiserade nummer, våran x punkt
    y = random.uniform(-1,1)  # Y, detta är våran första randomiserade nummer, våran y punkt
    plt.plot(x,y,'ro') #Vi sätter nu in plottern i loppen så att den skapar 10 olike punkter i diagrammet, om vi satte denna utanför loppen så skulle den endast visa dom högsta värden på diagrammet.
plt.xlim(-1,1) #Vi vill visa våran diagram mellan punkterna -1,1
plt.ylim(-1,1)
plt.show() # Vi sätter plt.show utanför loppen för att den inte ska skapa 10 olika diagram, den skapar endast 1 diagram med 10 punkter.

# %%
#Uppgift b
x = 15
y = 10

print(x/y)
# Out:
# 1.5

# %%
y = 1.5

print (y*4)
# Out:
# 6.0

# %%
import matplotlib.pyplot as plt  
import numpy as np
import random

figure,axes = plt.subplots()
draw_circle = plt.Circle((0,0),2, fill=False)



axes.set_aspect(1)
axes.add_artist(draw_circle)

for g in range(20):  #Här skapar vi våran loop
    x = random.uniform(-2,2)  # X, detta är våran första randomiserade nummer, våran x punkt
    y = random.uniform(-2,2) # Y, detta är våran första randomiserade nummer, våran y punkt
    

    
plt.ylim(-2,2)
plt.xlim(-2,2)
plt.show()

# %%
import matplotlib.pyplot as plt  
import numpy as np
import math

figure,axes = plt.subplots()
draw_circle = plt.Circle((0,0),2, fill=False)

axes.set_aspect(1)
axes.add_artist(draw_circle)

plt.axes()
rectangle = plt.Rectangle((-2,-2), 4, 4, fill=False)
plt.gca().add_patch(rectangle)
plt.axis('scaled')

#Här skapar vi våran loop
Nmax = 15
R = 2
r2 = R * np.sqrt(np.random.rand (Nmax, 1))
theta2 = 2 * np.pi * np.random.rand (Nmax,1)
x2 = r2 * np.cos(theta2)
y2 = r2 * np.sin(theta2)
plt.plot(x2,y2,'ro') # Y, detta är våran första randomiserade nummer, våran y punkt

area = R**2 * np.pi

inside = 0

for g in range(5):  #Här skapar vi våran loop
    x = random.uniform(-2,2)  # X, detta är våran första randomiserade nummer, våran x punkt
    y = random.uniform(-2,2) # Y, detta är våran första randomiserade nummer, våran y punkt
    


plt.ylim(-2,2)
plt.xlim(-2,2)
plt.show()

print(area)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-41a04f045ba9> in <module>
#      28
#      29 for g in range(5):  #Här skapar vi våran loop
# ---> 30     x = random.uniform(-2,2)  # X, detta är våran första randomiserade nummer, våran x punkt
#      31     y = random.uniform(-2,2) # Y, detta är våran första randomiserade nummer, våran y punkt
#      32
#
# NameError: name 'random' is not defined

# %%
import matplotlib.pyplot as plt
import random

circle = plt.Circle((.5,.55) , .07,color='b')
fig = plt.gcf()
fig.gca().add_artist(circle)

pointx = random.random()
pointy = random.random()
plt.scatter(pointx , pointy)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

figure,axes = plt.subplots()
draw_circle = plt.Circle((0,0),2, fill=False)


axes.set_aspect(1)
axes.add_artist(draw_circle)

Nmax = 15
R = 2

r2 = R * np.sqrt(np.random.rand (Nmax, 1))
theta2 = 2 * np.pi * np.random.rand (Nmax,1)
x2 = r2 * np.cos(theta2)
y2 = r2 * np.sin(theta2)


plt.plot(x2,y2,'ro')
plt.axis('square')


plt.ylim(-2,2)
plt.xlim(-2,2)
plt.show()

# %%
import matplotlib.pyplot as plt  
import numpy as np


figure,axes = plt.subplots()
draw_circle = plt.Circle((0,0),2, fill=False)



axes.set_aspect(1)
axes.add_artist(draw_circle)

dots = 20
x = np.random.rand (dots) 
y = np.random.rand (dots) 
plt.plot(x,y,'bo') 

plt.ylim(-2,2)
plt.xlim(-2,2)
plt.show()
